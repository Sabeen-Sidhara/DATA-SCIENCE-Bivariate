# %% [markdown]
# ## ** Download the dataset from <a href="https://drive.google.com/file/d/1hiR9XbTjMsNk_uA025w5nrw5LTBUDCEC/view?usp=sharing">here(Click Here)</a>

# %%
import pandas as pd
dataset=pd.read_csv('Placement_Data_Full_Class.csv')
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0      1.0      M  67.00   Others  91.00   Others  Commerce     58.00
# 1      2.0      M  79.33  Central  78.33   Others   Science     77.48
# 2      3.0      M  65.00  Central  68.00  Central      Arts     64.00
# 3      4.0      M  56.00  Central  52.00  Central   Science     52.00
# 4      5.0      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 212  211.0      M  80.60   Others  82.00   Others  Commerce     77.60
# 213  212.0      M  58.00   Others  60.00   Others   Science     72.00
# 214  213.0      M  67.00   Others  67.00   Others  Commerce     73.00
# 215  214.0      F  74.00   Others  66.00   Others  Commerce     58.00
# 216  215.0      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %% [markdown]
# ## 1)Replace the NaN values with correct value. And justify why you have chosen the same.

# %%
dataset.isna().sum()
# Out:
# sl_no              2
# gender             2
# ssc_p              2
# ssc_b              2
# hsc_p              2
# hsc_b              2
# hsc_s              2
# degree_p           2
# degree_t           2
# workex             2
# etest_p            2
# specialisation     2
# mba_p              2
# status             2
# salary            69
# dtype: int64

# %%
dataset=dataset.drop("sl_no",axis=1)
#dataset.fillna(method='ffill', inplace=True)
dataset
# Out:
#     gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p   degree_t  \
# 0        M  67.00   Others  91.00   Others  Commerce     58.00   Sci&Tech
# 1        M  79.33  Central  78.33   Others   Science     77.48   Sci&Tech
# 2        M  65.00  Central  68.00  Central      Arts     64.00  Comm&Mgmt
# 3        M  56.00  Central  52.00  Central   Science     52.00   Sci&Tech
# 4        M  85.80  Central  73.60  Central  Commerce     73.30  Comm&Mgmt
# ..     ...    ...      ...    ...      ...       ...       ...        ...
# 212      M  80.60   Others  82.00   Others  Commerce     77.60  Comm&Mgmt
# 213      M  58.00   Others  60.00   Others   Science     72.00   Sci&Tech
# 214      M  67.00   Others  67.00   Others  Commerce     73.00  Comm&Mgmt
# 215      F  74.00   Others  66.00   Others  Commerce     58.00  Comm&Mgmt
# 216      M  62.00  Central  58.00   Others   Science     53.00  Comm&Mgmt
#
#     workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
dataset["salary"].fillna(0,inplace=True)
dataset.dropna(inplace=True)

# %%
dataset.isnull().sum()
# Out:
# gender            0
# ssc_p             0
# ssc_b             0
# hsc_p             0
# hsc_b             0
# hsc_s             0
# degree_p          0
# degree_t          0
# workex            0
# etest_p           0
# specialisation    0
# mba_p             0
# status            0
# salary            0
# dtype: int64

# %% [markdown]
# ## 2)How many of them are not placed?

# %%
 dataset['status'].value_counts()
# Out:
# Placed        148
# Not Placed     67
# Name: status, dtype: int64

# %% [markdown]
# ## 3)Find the reason for non placement from the dataset?

# %%
placed = dataset[dataset['status'] == 'Placed']
placed
# Out:
#     gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p   degree_t  \
# 0        M  67.00   Others  91.00   Others  Commerce     58.00   Sci&Tech
# 1        M  79.33  Central  78.33   Others   Science     77.48   Sci&Tech
# 2        M  65.00  Central  68.00  Central      Arts     64.00  Comm&Mgmt
# 4        M  85.80  Central  73.60  Central  Commerce     73.30  Comm&Mgmt
# 9        M  82.00  Central  64.00  Central   Science     66.00   Sci&Tech
# ..     ...    ...      ...    ...      ...       ...       ...        ...
# 211      M  62.00  Central  72.00  Central  Commerce     65.00  Comm&Mgmt
# 212      M  80.60   Others  82.00   Others  Commerce     77.60  Comm&Mgmt
# 213      M  58.00   Others  60.00   Others   Science     72.00   Sci&Tech
# 214      M  67.00   Others  67.00   Others  Commerce     73.00  Comm&Mgmt
# 215      F  74.00   Others  66.00   Others  Commerce     58.00  Comm&Mgmt
#
#     workex  etest_p specialisation  mba_p  status    salary
# ...

# %%
Nplaced = dataset[dataset['status'] == 'Not Placed']
Nplaced
# Out:
#     gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p   degree_t  \
# 3        M   56.0  Central   52.0  Central   Science     52.00   Sci&Tech
# 5        M   55.0   Others   49.8   Others   Science     67.25   Sci&Tech
# 6        F   46.0   Others   49.2   Others  Commerce     79.00  Comm&Mgmt
# 11       M   58.0  Central   70.0  Central  Commerce     61.00  Comm&Mgmt
# 14       F   47.0  Central   55.0   Others   Science     65.00  Comm&Mgmt
# ..     ...    ...      ...    ...      ...       ...       ...        ...
# 200      F   67.0  Central   70.0  Central  Commerce     65.00     Others
# 203      M   54.2  Central   63.0   Others   Science     58.00  Comm&Mgmt
# 208      M   41.0  Central   42.0  Central   Science     60.00  Comm&Mgmt
# 210      F   43.0  Central   60.0   Others   Science     65.00  Comm&Mgmt
# 216      M   62.0  Central   58.0   Others   Science     53.00  Comm&Mgmt
#
#     workex  etest_p specialisation  mba_p      status  salary
# ...

# %% [markdown]
# The Information in the dataset are seems to be similar when compared between Placed and Not placed.
# The lowest marks scored students are also placed, at the sametime the highest marks scored students are also not placed.
# Herewith my conclusion is the given dataset is insufficient. Because of the reason,above I mentioned is same as for departments and experienced persons.
# So based on their interview performance only we can tell the reason for Student's placement. The Interview or HR feedback data is missing in our dataset.From That only we can tell the exact reason, why the students are not placed.

# %% [markdown]
# ## 4)What kind of relation between salary and mba_p

# %% [markdown]
# # correlation between salary and mba_p

# %%
dataset.corr()
# Out:
#              ssc_p     hsc_p  degree_p   etest_p     mba_p    salary
# ssc_p     1.000000  0.511472  0.538404  0.261993  0.388478  0.538090
# hsc_p     0.511472  1.000000  0.434206  0.245113  0.354823  0.452569
# degree_p  0.538404  0.434206  1.000000  0.224470  0.402364  0.408371
# etest_p   0.261993  0.245113  0.224470  1.000000  0.218055  0.186988
# mba_p     0.388478  0.354823  0.402364  0.218055  1.000000  0.139823
# salary    0.538090  0.452569  0.408371  0.186988  0.139823  1.000000

# %% [markdown]
# Correlation for MBA Examination and Salary:
# Relationship Between MBA Examination and Salary. mba_p and salary is 0.139823.
# It has Positive Correlation Value.
# So it belongs to Low Degree of Positive Correlation.

# %% [markdown]
# ## 5)Which specialization is getting minimum salary?

# %%
Min_Sal=dataset['specialisation']['Min']=dataset['salary'].min()
# Out:
# C:\sabeen\anaconda3\envs\aiml\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
Min_Sal
# Out:
# 0.0

# %% [markdown]
# ## 6)How many of them getting above 500000 salary?

# %%
(dataset['salary'] > 500000).sum()
# Out:
# 3

# %% [markdown]
# ## 7)Test the Analysis of Variance between etest_p and mba_p at signifance level 5%.(Make decision using Hypothesis Testing)

# %% [markdown]
# # ANAVO One Way Classification

# %%
import scipy.stats as stats
stats.f_oneway(dataset["etest_p"],dataset["mba_p"])
# Out:
# F_onewayResult(statistic=98.64487057324706, pvalue=4.672547689133573e-21)

# %% [markdown]
# Analysis of Variance-test yielded a p-value of 4.672547689133573e-21
# This result indicates a very significant difference between the two groups.
# The p-value of 4.672547689133573e-21, which is much smaller than 0.05,it reject the null hypothesis (H0).
# It indicates that there is statistically significant evidence to support the alternative hypothesis(H1).

# %% [markdown]
# ## 8)Test the similarity between the degree_t(Sci&Tech) and specialisation(Mkt&HR) with respect to salary  at significance level of 5%.(Make decision using Hypothesis Testing)

# %% [markdown]
# # Independent Sample=Unpaired T-Test (Different Group But Same Condition.)

# %%
from scipy.stats import ttest_ind
dataset=dataset.dropna()
st=dataset[dataset['degree_t'] == 'Sci&Tech']['salary']
mkt = dataset[dataset['specialisation'] == 'Mkt&HR']['salary']
ttest_ind(st,mkt)
# Out:
# Ttest_indResult(statistic=2.692041243555374, pvalue=0.007897969943471179)

# %% [markdown]
# The p-value of 0.007897969943471179, which is much smaller than 0.05,it reject the null hypothesis (H0).
# It indicates that there is statistically significant evidence to support the alternative hypothesis(H1).

# %% [markdown]
# ## 9)Convert the normal distribution to standard normal distribution for salary column

# %%
#convert Normal Distribution to Standard Normal Distribution 
def StdND_graph(dataset):#we give dataset as an input
    import seaborn as sns #seaborn is a library
    mean=dataset.mean()#we find Mean and Standard Deviation for the columns .
    std=dataset.std()
    #values=[value for value in dataset]#in this for loop .we converted the dataset into List.
    values=[]
    for value in dataset:
        values.append(value)
    z_score=[((j-mean)/std)for j in values]#To find Z-Score .We use the formula. j is value minus Mean divided by std .
    #then we do for loop for the values to get Z-score.
    sns.distplot(z_score,kde=True,kde_kws={'color':'red'},color='Green')#we have to give kde= True ,to have bell shaped graph.
    #with Red color.Histogram -Green color.
    sum(z_score)/len(z_score)#total sum of all the elements in z_score/number of elements in z_score to find the average.

# %%
StdND_graph(dataset['salary'])
# Out:
# C:\sabeen\anaconda3\envs\aiml\lib\site-packages\ipykernel_launcher.py:12: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   if sys.path[0] == "":

# %% [markdown]
# ## 10)What is the probability Density Function of the salary range from 700000 to 900000?

# %%
def get_pdf_probability(dataset,startrange,endrange):
    from matplotlib import pyplot
    from scipy.stats import norm
    import seaborn as sns           #we are importing the libraries.
    ax=sns.distplot(dataset,kde=True,kde_kws={'color':'red'},color='Green')#distplot is a function from seaborn library.
    #kde-Kernel Density Estimation
    #we have to give True ,to have bell shaped graph. with Red color.Histogram -Green color.
    pyplot.axvline(startrange,color='violet')#axvline=axis vertical line with violet colour in startrange and endrange.
    pyplot.axvline(endrange,color='violet')#we get the startrange and endrange value from the user
    #generate the sample
    sample=dataset 
    #calculate the parameters
    sample_mean=sample.mean()#we need the value of mean and standard deviation 
    sample_std=sample.std()
    print('Mean=%.3f,StandardDeviation=%.3f'%(sample_mean,sample_std))
    #define the distribution
    dist=norm(sample_mean,sample_std)#we use inbuild function for normal distribution.we import norm from scipy.stats.
    #from this norm we give mean and standard deviation as an input.from these norm it learns about the distribution pattern.
    #sample probabilities for a range of outcomes.
    values=[value for value in range(startrange,endrange)]#We do for loop in one line .in a single line it convert to list
    probabilities=[dist.pdf(value)for value in values]#we pass the values in dist.pdf using for loop to get the probability
    prob=sum(probabilities)#doing sumation for the Probability 
    print('The area between range({},{}):{}'.format(startrange,endrange,sum(probabilities)))
    prob

# %%
get_pdf_probability(dataset['salary'],70000,90000)
# Out:
# C:\sabeen\anaconda3\envs\aiml\lib\site-packages\ipykernel_launcher.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   """
# Mean=198702.326,StandardDeviation=154780.927
# The area between range(70000,90000):0.038404601457347365

# %% [markdown]
# ## 11)Test the similarity between the degree_t(Sci&Tech)with respect to etest_p and mba_p at significance level of 5%.(Make decision using Hypothesis Testing)

# %% [markdown]
# # Dependent Sample= Paired T-Test (Same Group But  DifferentCondition.)

# %%
from scipy.stats import ttest_rel
dataset=dataset.dropna()
com=dataset[dataset['degree_t']=='Sci&Tec']['etest_p']
com1=dataset[dataset['degree_t']=='Sci&Tec']['mba_p']
ttest_rel(com,com1)
# Out:
# Ttest_relResult(statistic=nan, pvalue=nan)

# %% [markdown]
# When we get a result of nan (not a number) for both the statistic and p-value in a paired t-test, it typically indicates that there are issues with Insufficient Datas or Missing Values or Constant Values or Data Type Issues

# %% [markdown]
# ## 12)Which parameter is highly correlated with salary?

# %%
df=dataset.corr()
df['salary']
# Out:
# ssc_p       0.538090
# hsc_p       0.452569
# degree_p    0.408371
# etest_p     0.186988
# mba_p       0.139823
# salary      1.000000
# Name: salary, dtype: float64

# %% [markdown]
# The parameter which is highly correlated with salary is ssc_p, with a correlation coefficient of 0.538090. This indicates a moderate positive correlation

# %% [markdown]
# ## 13) plot  any useful graph and explain it.

# %%
import seaborn as sns
sns.pairplot(dataset,hue="degree_t")

import matplotlib.pyplot as plt
plt.savefig('pairplot_degree_t.png')
